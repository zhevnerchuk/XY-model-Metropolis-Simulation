# %%
import numpy as np
data = np.load('data.npy')

# %%
import matplotlib.pylab as plt

# %%
plt.rcParams['figure.figsize'] = (24,15)
plt.rcParams['font.size'] = 24

# %%
plt.plot(data[:,0], data[:,1])
plt.axvline(1.0, color='b', linestyle='dashed', linewidth=2)
plt.axvline(1.25, color='b', linestyle='dashed', linewidth=2)

plt.xlabel('temperature')
plt.ylabel('Correlation length')
plt.show()

# %%
plt.plot(data[:,0], data[:,2])
plt.xlabel('temperature')
plt.ylabel('specific heat')
plt.axvline(data[np.argmax(data[:, 2]), 0], color='b', linestyle='dashed', linewidth=2)
plt.show()

# %%
from xy import *

# %%
GetXYAnimation((20, 20), beta=2, steps=1000, iters_per_step=100, filename='anti.mp4', J=-1, random_state=25)

# %%
GetXYAnimation((20, 20), beta=0.01, steps=1000, iters_per_step=100, filename='high_temperature.mp4', random_state=25)

# %%
GetXYAnimation((20, 20), beta=10, steps=1000, iters_per_step=100, filename='low_temperature.mp4', random_state=25)
